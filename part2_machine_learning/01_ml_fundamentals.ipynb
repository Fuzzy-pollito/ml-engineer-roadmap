# %% [markdown]
# # Machine Learning Fundamentals
#
# ## Objective
# Understand the core machine learning workflow by:
# - Defining supervised learning
# - Understanding features and targets
# - Training a simple model
# - Evaluating model performance
#
# ## Why this matters
# Every ML project—simple or complex—follows the same core steps.
# Understanding these fundamentals prevents common mistakes later.
